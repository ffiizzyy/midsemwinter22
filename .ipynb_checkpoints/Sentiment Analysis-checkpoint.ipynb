# %%
import pandas as pd
from textblob import TextBlob
import nltk
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Load CSV
df = pd.read_csv("reviews_dec18.csv")

df['comments'] = df['comments'].astype(str)

# List how many unique places are reviewed
num_unique_values = df['listing_id'].nunique()

unique_values = df['listing_id'].unique()

unique_values
# Out:
# array([    9835,    10803,    12936, ..., 30490522, 30518693, 30540943])

# %%
# Choose listing number and create subset

listing_id_chosen = 10803
subset = df.loc[df['listing_id'] == listing_id_chosen, :].copy()

display(subset)
# Out:
#      listing_id         id        date  reviewer_id   reviewer_name  \
# 4         10803    3333588  2013-01-12      4421189        Johannes
# 5         10803    3369053  2013-01-18      1763045           Julie
# 6         10803    3403930  2013-01-23      4423532          Ivonne
# 7         10803    3514479  2013-02-11      4551787            Jess
# 8         10803    3662039  2013-03-01       632036  Yvonne And Pip
# ..          ...        ...         ...          ...             ...
# 107       10803  344129941  2018-11-02    122471750         Tatiana
# 108       10803  348444786  2018-11-13    145498403             Sam
# 109       10803  349610018  2018-11-18     49369979         Kenneth
# 110       10803  350947244  2018-11-21      5040075             Tam
# 111       10803  352879230  2018-11-26    129236612          Martin
#
#                                               comments
# 4    It was very convenient  to stay in Lindsay's a...
# 5    Perfect isnt enough! Lindsay was the best host...
# 6    Living with Lindsay was very relaxed. The room...
# 7    Beautiful home, great location very friendly a...
# 8    It was great staying at Lindsay's apartment. H...
# ..                                                 ...
# 107  Very nice and clean place. Hightly recommend it )
# 108  Cleanliness is an issue. Dust, clutter and rar...
# 109  Great cosy room in an awesome apartment that g...
# 110  Super unique space in a very trendy neighborhood!
# 111                            Sehr relaxte Unterkunft
#
# [108 rows x 6 columns]

# %%
# Determine polarity

#If polarity <0 = negative, =0 means neutral, >0 positive
subset.loc[:, 'polarity'] = subset['comments'].apply(lambda 
                x: TextBlob(x).sentiment.polarity)

# Determine subjectivity
subset.loc[:, 'subjectivity'] = subset['comments'].apply(lambda 
                x: TextBlob(x).sentiment.subjectivity)

# %%
# Extract part-of-speech tags from the 'comments' column
subset.loc[:, 'pos_tags'] = subset['comments'].apply(lambda 
                x: TextBlob(x).pos_tags)

# Define a function that returns the nouns in a list of tuples
def get_nouns(tags):
    nouns = [word for word, pos in tags if pos == "NN"]
    return nouns

# Apply the get_nouns function to the 'pos_tags' column
subset.loc[:, 'nouns'] = subset['pos_tags'].apply(get_nouns)

display(subset)
# Out:
#      listing_id         id        date  reviewer_id   reviewer_name  \
# 4         10803    3333588  2013-01-12      4421189        Johannes
# 5         10803    3369053  2013-01-18      1763045           Julie
# 6         10803    3403930  2013-01-23      4423532          Ivonne
# 7         10803    3514479  2013-02-11      4551787            Jess
# 8         10803    3662039  2013-03-01       632036  Yvonne And Pip
# ..          ...        ...         ...          ...             ...
# 107       10803  344129941  2018-11-02    122471750         Tatiana
# 108       10803  348444786  2018-11-13    145498403             Sam
# 109       10803  349610018  2018-11-18     49369979         Kenneth
# 110       10803  350947244  2018-11-21      5040075             Tam
# 111       10803  352879230  2018-11-26    129236612          Martin
#
#                                               comments  polarity  \
# 4    It was very convenient  to stay in Lindsay's a...  0.300000
# 5    Perfect isnt enough! Lindsay was the best host...  0.368182
# 6    Living with Lindsay was very relaxed. The room...  0.326250
# 7    Beautiful home, great location very friendly a...  0.753125
# 8    It was great staying at Lindsay's apartment. H...  0.465649
# ..                                                 ...       ...
# 107  Very nice and clean place. Hightly recommend it )  0.573333
# 108  Cleanliness is an issue. Dust, clutter and rar...  0.227530
# 109  Great cosy room in an awesome apartment that g...  0.808333
# 110  Super unique space in a very trendy neighborhood!  0.561111
# 111                            Sehr relaxte Unterkunft  0.000000
#
#      subjectivity                                           pos_tags  \
# 4        0.706667  [(It, PRP), (was, VBD), (very, RB), (convenien...
# 5        0.419580  [(Perfect, NNP), (isnt, VBZ), (enough, JJ), (L...
# 6        0.586250  [(Living, VBG), (with, IN), (Lindsay, NNP), (w...
# 7        0.800000  [(Beautiful, NNP), (home, NN), (great, JJ), (l...
# 8        0.540909  [(It, PRP), (was, VBD), (great, JJ), (staying,...
# ..            ...                                                ...
# 107      0.850000  [(Very, RB), (nice, JJ), (and, CC), (clean, JJ...
# 108      0.382391  [(Cleanliness, NNP), (is, VBZ), (an, DT), (iss...
# 109      0.889583  [(Great, NNP), (cosy, JJ), (room, NN), (in, IN...
# 110      0.888889  [(Super, NNP), (unique, JJ), (space, NN), (in,...
# 111      0.000000    [(Sehr, NNP), (relaxte, NN), (Unterkunft, NNP)]
#
#                                                  nouns
# 4         [appartment, couple, host, appartment, part]
# 5    [host, help, lot, start, australia, place, loc...
# 6                [room, colours, person, lot, journey]
# 7                               [home, location, stay]
# 8    [apartment, fun, bevie, location, tram, step, ...
# ..                                                 ...
# 107                                            [place]
# 108  [issue, clutter, sink, hob, food, end, cutlery...
# 109            [room, apartment, location, tram, city]
# 110                              [space, neighborhood]
# 111                                          [relaxte]
#
# [108 rows x 10 columns]

# %%
# Create a list of the nouns in the 'nouns' column
noun = [word for tags in subset['nouns'] for word in tags]

# Join the nouns into a single string
text = " ".join(noun)

# Create a WordCloud object
wordcloud = WordCloud(background_color='white', max_words=100).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Count the number of rows with a polarity value less than 0
count = subset[subset['polarity'] < 0].shape[0]

print(count)

# Learn more about the reviews

print(subset['polarity'].describe())
print(subset['subjectivity'].describe())
# Out:
# 1
# count    108.000000
# mean       0.362191
# std        0.210560
# min       -0.100000
# 25%        0.215023
# 50%        0.375464
# 75%        0.500000
# max        1.000000
# Name: polarity, dtype: float64
# count    108.000000
# mean       0.569014
# std        0.220367
# min        0.000000
# 25%        0.486881
# 50%        0.600000
# 75%        0.700000
# max        1.000000
# Name: subjectivity, dtype: float64

# %%
subset_negative = subset[subset['polarity'] < 0]

subset_positive = subset[subset['polarity'] > 0]

# %%
# Create negative review WordCloud 
try:
    negative_noun = [word for tags in subset_negative['nouns'] for word in tags]
    negative_text = " ".join(negative_noun)


    negative_wordcloud = WordCloud(background_color='white', max_words=100).generate(negative_text)
    plt.imshow(negative_wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

except:
    print("There are no negative reviews")

# %%
# Create positive review WordCloud 
try: 
    positive_noun = [word for tags in subset_positive['nouns'] for word in tags]
    positive_text = " ".join(positive_noun)


    positive_wordcloud = WordCloud(background_color='white', max_words=100).generate(positive_text)
    plt.imshow(positive_wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    
except: 
    print("There are no positive reviews")

# %%
# Count and order the frequency of the most popular words
def returnWordCount(wordList) :
    word_counts = Counter(wordList)
    items = list(word_counts.items())
    sorted_items = sorted(items, key=lambda x: x[1], reverse=True)
    word_output = pd.DataFrame(sorted_items, columns=['Word', 'Frequency'])
    return word_output

print(returnWordCount(positive_noun))
print(returnWordCount(negative_noun))
# Out:
#             Word  Frequency
# 0           room         58
# 1          place         49
# 2       location         40
# 3           host         37
# 4           tram         35
# ..           ...        ...
# 363      cooking          1
# 364         dark          1
# 365        trick          1
# 366  bed/private          1
# 367        clean          1
#
# [368 rows x 2 columns]
#       Word  Frequency
# 0  bedroom          1
# 1    house          1

# %%
# # List most popular keywords from positive reviews
# positive_counts = Counter(positive_noun)
# items = list(positive_counts.items())
# sorted_items = sorted(items, key=lambda x: x[1], reverse=True)
# positive_words = pd.DataFrame(sorted_items, columns=['Word', 'Frequency'])

# # List most popular keywords from negative reviews
# negative_counts = Counter(negative_noun)
# items = list(negative_counts.items())
# sorted_items = sorted(items, key=lambda x: x[1], reverse=True)
# negative_words = pd.DataFrame(sorted_items, columns=['Word', 'Frequency'])
# Out:
#          Word  Frequency
# 0   apartment         11
# 1    location          8
# 2       place          8
# 3       beach          4
# 4      couple          3
# ..        ...        ...
# 63        car          1
# 64       stay          1
# 65    process          1
# 66      odour          1
# 67          t          1
#
# [68 rows x 2 columns]
